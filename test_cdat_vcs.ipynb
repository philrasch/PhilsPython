# %%
#These imports are added for vcdat.
import cdms2
import vcs
import numpy

# %%
#Create canvas
canvas = vcs.init()

# %%
file_data = cdms2.open('CMIP6_DATA/ERA-Interim/ei.moda.an.ml.nc/ei.moda.an.ml.regn128sc.1979020100.nc')
Q_GDS4_HYBL_S123 = file_data("Q_GDS4_HYBL_S123", lv_HYBL2=(1, 60), g4_lat_0=(-89.46282196044922, 89.46282196044922), g4_lon_1=(0, 359.2969970703125))
file_data.close()

# %%
a_polar_boxfill = vcs.getboxfill('a_polar_boxfill')

# %%
canvas.clear()
canvas.plot(Q_GDS4_HYBL_S123, "default", a_polar_boxfill)

# %%
file_data = cdms2.open('CMIP6_DATA/ERA-Interim/ei.moda.an.ml.nc/ei.moda.an.ml.regn128sc.1979020100.nc')
Q_GDS4_HYBL_S123 = file_data("Q_GDS4_HYBL_S123", lv_HYBL2=(1, 60), g4_lat_0=(89.46282196044922, 10.877172470092773), g4_lon_1=(0, 359.2969970703125))
file_data.close()

# %%
Q_GDS4_HYBL_S123.info()
Q = Q_GDS4_HYBL_S123.copy()
Q = Q*1.e3
Q.units = 'g/kg'
# Out:
# *** Description of Slab Q_GDS4_HYBL_S123 ***
# id: Q_GDS4_HYBL_S123
# shape: (60, 256, 512)
# filename:
# missing_value: 1e+20
# comments:
# grid_name: <None>
# grid_type: generic
# time_statistic:
# long_name: Specific humidity
# units: kg kg**-1
# tileIndex: None
# N: [112]
# statistical_process_duration: instantaneous (beginning at reference time at intervals of 6 hours)
# statistical_process_descriptor: average of N uninitialized analyses
# initial_time: 02/01/1979 (00:00)
# forecast_time_units: hours
# forecast_time: [0]
# parameter_number: [133]
# parameter_table_version: [128]
# gds_grid_type: [4]
# level_indicator: [109]
# center: European Center for Medium-Range Weather Forecasts (RSMC)
# Grid has Python id 0x2aaadbf7f908.
# Gridtype: generic
# Grid shape: (256, 512)
# Order: yx
# ** Dimension 1 **
#    id: lv_HYBL2
#    units:  number
#    Length: 60
#    First:  1
#    Last:   60
#    Other axis attributes:
#       long_name: hybrid level
# ...
