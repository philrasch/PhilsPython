# %%
import sys
print(sys.version)
# %matplotlib inline
# %run -i ~/Python/pjr3
# Out:
# 3.7.5 (default, Oct 25 2019, 10:52:18)
# [Clang 4.0.1 (tags/RELEASE_401/final)]
# pjr3.py complete

# %%
print ("two vals of pi", np.pi, pi)
# Out:
# two vals of pi 3.141592653589793 3.141592653589793

# %%
findNiceContours?
# Out:
# Signature: findNiceContours(data, nlevs=None, rmClev=None, sym=None, verbose=None)
# Docstring:
# Find Nice Contours
# data = 2d numpy array (or data structure base on numpy) ordered (latitude, pressure)
# nlevs = approximate number of contour levels to return (default 10)
# rmClev = if defined delete the contour level near this value
# sym = if defined make the contour intervals symmetric about zero
# verbose = if defined, print out some info to help debug
# File:      ~/Python/pjr3.py
# Type:      function

# %%
plotZMf?
# Out:
# Signature:
# plotZMf(
#     data,
#     x,
#     y,
#     plotOpt=None,
#     modelLevels=None,
#     surfacePressure=None,
#     axesa=None,
#     fig=None,
# )
# Docstring:
# Create a zonal mean contour plot of one variable
# axesa = the axes that we make the plot on
# data = 2d numpy array (or data structure base on numpy) ordered (latitude, pressure)
# x = 1d numpy array of latitude
# y = 1d numpy array of pressures (or pseudo pressure (like eta))
# plotOpt is a optional dictionary with plotting options:
#   'scale_factor': multiply values with this factor before plotting
#   'units': a units label for the colorbar
#   'clevs': use list of values as contour intervals
#   'cmap': the color map to use
#   'cabv': the above color
#   'cbel': the below color
#   'colorbar': location of colorbar ('bot','top','left','right','None')
#   'rmClev': contour level to delete; frequently Zero, see findNiceContours
#   'title': a title for the plot
# ...

# %%
DS = xr.open_dataset('~/NetCDF_Files/CRUprecip_regionalmean_20032014-0405.nc')
print (DS)
da = DS.pre
time = DS.time
#print (time, da)
DS2 = xr.open_dataset('~/NetCDF_Files/GPCPprecip_regionalmean_20032014-0405.nc')
#print (DS2)
da2 = DS2.pre
da.plot(label='CRU')
da2.plot(label='GPCP')
plt.legend()
plt.show()
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 12)
# Coordinates:
#   * time     (time) int32 2003 2004 2005 2006 2007 ... 2010 2011 2012 2013 2014
# Data variables:
#     pre      (time) float32 ...

# %%
DS = xr.open_dataset('~/NetCDF_Files/GF4_025x025_regionalmean_20032014-0405.nc')
print (DS)
da = DS.DM_TOTL
time = DS.time
print (time, da)
da.plot()
plt.show()
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 12)
# Coordinates:
#   * time     (time) int32 2003 2004 2005 2006 2007 ... 2010 2011 2012 2013 2014
# Data variables:
#     DM_TOTL  (time) float32 ...
# <xarray.DataArray 'time' (time: 12)>
# array([2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014],
#       dtype=int32)
# Coordinates:
#   * time     (time) int32 2003 2004 2005 2006 2007 ... 2010 2011 2012 2013 2014 <xarray.DataArray 'DM_TOTL' (time: 12)>
# array([4.075426, 0.555478, 2.500205, 1.666943, 1.891675, 1.475782, 1.990336,
#        0.91711 , 2.597967, 0.594589, 2.301972, 0.777812], dtype=float32)
# Coordinates:
#   * time     (time) int32 2003 2004 2005 2006 2007 ... 2010 2011 2012 2013 2014
# Attributes:
#     units:      x10-9 kg/m2/s
#     long_name:  Total dry matter conbustion rate

# %%
DS = xr.open_dataset('~/NetCDF_Files/GF4_025x025_regionalmean_20032014-0405.nc')
print (DS)
da = DS.DM_TOTL
time = DS.time
print (time, da)
da.plot()
plt.show()
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 12)
# Coordinates:
#   * time     (time) int32 2003 2004 2005 2006 2007 ... 2010 2011 2012 2013 2014
# Data variables:
#     DM_TOTL  (time) float32 ...
# <xarray.DataArray 'time' (time: 12)>
# array([2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014],
#       dtype=int32)
# Coordinates:
#   * time     (time) int32 2003 2004 2005 2006 2007 ... 2010 2011 2012 2013 2014 <xarray.DataArray 'DM_TOTL' (time: 12)>
# array([4.075426, 0.555478, 2.500205, 1.666943, 1.891675, 1.475782, 1.990336,
#        0.91711 , 2.597967, 0.594589, 2.301972, 0.777812], dtype=float32)
# Coordinates:
#   * time     (time) int32 2003 2004 2005 2006 2007 ... 2010 2011 2012 2013 2014
# Attributes:
#     units:      x10-9 kg/m2/s
#     long_name:  Total dry matter conbustion rate

# %%
DS = xr.open_dataset('~/NetCDF_Files/GPCP_pre_dd_20000101-20141231.nc')
print (DS)
da = DS.pre
time = DS.time
print (time, da)
da.plot()
plt.show()
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 5479)
# Coordinates:
#   * time     (time) datetime64[ns] 2000-01-01T12:00:00 ... 2014-12-31T12:00:00
# Data variables:
#     pre      (time) float32 ...
# <xarray.DataArray 'time' (time: 5479)>
# array(['2000-01-01T12:00:00.000000000', '2000-01-02T12:00:00.000000000',
#        '2000-01-03T12:00:00.000000000', ..., '2014-12-29T12:00:00.000000000',
#        '2014-12-30T12:00:00.000000000', '2014-12-31T12:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 2000-01-01T12:00:00 ... 2014-12-31T12:00:00
# Attributes:
#     long_name:  time <xarray.DataArray 'pre' (time: 5479)>
# array([0.402073, 0.104314, 0.044539, ..., 0.572271, 0.261063, 3.868066],
#       dtype=float32)
# Coordinates:
#   * time     (time) datetime64[ns] 2000-01-01T12:00:00 ... 2014-12-31T12:00:00
# Attributes:
#     average_op_ncl:  dim_avg_n over dimension(s): lat
#     version:         v1.2
#     units:           mm/day
# ...

# %%
DS = xr.open_dataset('~/NetCDF_Files/CRU_pre_mm_199101-201412.nc')
print (DS)
da = DS.pre
time = DS.time
print (time, da)
da.plot()
plt.show()
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 288)
# Coordinates:
#   * time     (time) datetime64[ns] 1991-01-16 1991-02-15 ... 2014-12-16
# Data variables:
#     pre      (time) float32 ...
# <xarray.DataArray 'time' (time: 288)>
# array(['1991-01-16T00:00:00.000000000', '1991-02-15T00:00:00.000000000',
#        '1991-03-16T00:00:00.000000000', ..., '2014-10-16T00:00:00.000000000',
#        '2014-11-16T00:00:00.000000000', '2014-12-16T00:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 1991-01-16 1991-02-15 ... 2014-12-16
# Attributes:
#     axis:           T
#     long_name:      time
#     standard_name:  time <xarray.DataArray 'pre' (time: 288)>
# array([ 51.432735,  29.293499,  18.141256, ..., 296.19775 , 124.71233 ,
#         60.42534 ], dtype=float32)
# Coordinates:
#   * time     (time) datetime64[ns] 1991-01-16 1991-02-15 ... 2014-12-16
# Attributes:
#     average_op_ncl:              dim_avg_n over dimension(s): lat
# ...

# %%
DS = xr.open_dataset('~/NetCDF_Files/GF4_mm_200301-201412.nc')
print (DS)
da = DS.DM_TOTL
time = DS.time
print (time, da)
da.plot()
plt.show()
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 144)
# Coordinates:
#   * time     (time) datetime64[ns] 2003-01-01 2003-02-01 ... 2014-12-01
# Data variables:
#     DM_TOTL  (time) float32 ...
# <xarray.DataArray 'time' (time: 144)>
# array(['2003-01-01T00:00:00.000000000', '2003-02-01T00:00:00.000000000',
#        '2003-03-01T00:00:00.000000000', '2003-04-01T00:00:00.000000000',
#        '2003-05-01T00:00:00.000000000', '2003-06-01T00:00:00.000000000',
#        '2003-07-01T00:00:00.000000000', '2003-08-01T00:00:00.000000000',
#        '2003-09-01T00:00:00.000000000', '2003-10-01T00:00:00.000000000',
#        '2003-11-01T00:00:00.000000000', '2003-12-01T00:00:00.000000000',
#        '2004-01-01T00:00:00.000000000', '2004-02-01T00:00:00.000000000',
#        '2004-03-01T00:00:00.000000000', '2004-04-01T00:00:00.000000000',
#        '2004-05-01T00:00:00.000000000', '2004-06-01T00:00:00.000000000',
#        '2004-07-01T00:00:00.000000000', '2004-08-01T00:00:00.000000000',
# ...

# %%
DS = xr.open_dataset('~/NetCDF_Files/GF4_dd_20030101-20141231.nc')
print (DS)
da = DS.DM_TOTL
time = DS.time
print (time, da)
da.plot()
plt.show()
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 4383)
# Coordinates:
#   * time     (time) datetime64[ns] 2003-01-01 2003-01-02 ... 2014-12-31
# Data variables:
#     DM_TOTL  (time) float32 ...
# <xarray.DataArray 'time' (time: 4383)>
# array(['2003-01-01T00:00:00.000000000', '2003-01-02T00:00:00.000000000',
#        '2003-01-03T00:00:00.000000000', ..., '2014-12-29T00:00:00.000000000',
#        '2014-12-30T00:00:00.000000000', '2014-12-31T00:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 2003-01-01 2003-01-02 ... 2014-12-31 <xarray.DataArray 'DM_TOTL' (time: 4383)>
# array([4.050709e-11, 5.184764e-11, 4.392830e-11, ..., 4.910164e-11,
#        5.366830e-11, 4.982012e-11], dtype=float32)
# Coordinates:
#   * time     (time) datetime64[ns] 2003-01-01 2003-01-02 ... 2014-12-31
# Attributes:
#     average_op_ncl:  dim_avg_n over dimension(s): lat
#     units:           kg/m2/s

# %%
TZ.plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/Python/pjr3.py in <module>
# ----> 1 TZ.plot()
#       2 plt.show()
#
# NameError: name 'TZ' is not defined

# %%
da = DS.PS# Draw coastlines of the Earth
ax = plt.axes(projection=ccrs.PlateCarree())
ax.coastlines() 



da.plot()
plt.show()

# %%
TS = DS.TS# Draw coastlines of the Earth
TS = TS.isel(time=0)
ax = plt.axes(projection=ccrs.Robinson())
ax.coastlines()
lon = TS['lon']
lat = TS['lat']
ax.contourf(lon, lat, TS, transform=ccrs.PlateCarree())

da.plot()
plt.show()
